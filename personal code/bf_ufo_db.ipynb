# %%
import pandas as pd
from sqlalchemy import create_engine
#extras
import os

# %%
# tried to merge... did not work.

#a = pd.read_csv("Resources/ufo.complete.csv")
#b = pd.read_csv("Resources/bfro_reports_geocoded.csv")
#b = b.dropna(axis=1)
#merged = a.merge(b, on='state')
#merged.to_csv("bfufo.csv", index=False)

# %%
csv_file = "Resources/ufo.complete.csv"
ufo_data_df = pd.read_csv(csv_file, error_bad_lines=False)
ufo_data_df.head(1)
# Out:
# b'Skipping line 878: expected 11 fields, saw 12\nSkipping line 1713: expected 11 fields, saw 12\nSkipping line 1815: expected 11 fields, saw 12\nSkipping line 2858: expected 11 fields, saw 12\nSkipping line 3734: expected 11 fields, saw 12\nSkipping line 4756: expected 11 fields, saw 12\nSkipping line 5389: expected 11 fields, saw 12\nSkipping line 5423: expected 11 fields, saw 12\nSkipping line 5614: expected 11 fields, saw 12\nSkipping line 5849: expected 11 fields, saw 12\nSkipping line 6093: expected 11 fields, saw 12\nSkipping line 7516: expected 11 fields, saw 12\nSkipping line 7626: expected 11 fields, saw 12\nSkipping line 8893: expected 11 fields, saw 12\nSkipping line 9015: expected 11 fields, saw 12\nSkipping line 9571: expected 11 fields, saw 12\nSkipping line 9620: expected 11 fields, saw 12\nSkipping line 9751: expected 11 fields, saw 12\nSkipping line 10157: expected 11 fields, saw 12\nSkipping line 10427: expected 11 fields, saw 12\nSkipping line 12035: expected 11 fi
# ...

# %%
merge_df_rename = merge_df.rename(columns={'date posted': 'date'})
merge_df_rename.head()
# Out:
#   date state title  latitude  longitude_x                   location_details  \
# 0  NaN    ak   NaN       NaN          NaN  East side of Prince William Sound
# 1  NaN    ak   NaN       NaN          NaN  East side of Prince William Sound
# 2  NaN    ak   NaN       NaN          NaN  East side of Prince William Sound
# 3  NaN    ak   NaN       NaN          NaN  East side of Prince William Sound
# 4  NaN    ak   NaN       NaN          NaN  East side of Prince William Sound
#
#          date  longitude_y
# 0  10/30/2006  -149.728889
# 1  10/12/2001  -147.716389
# 2   12/7/2006  -146.768611
# 3   1/28/1999  -161.903334
# 4  11/20/2001  -149.567778

# %%
#clean up ufo data to colums needed.
ufo_data_df = ufo_data_df[['date posted', 'state', 'longitude']].copy()
ufo_data_df.head(1)
# Out:
#   date posted state  longitude
# 0   4/27/2004    tx -97.941111

# %%
# Estract bf info from CSV file.

csv_file = "Resources/clean_bf_reports.csv"
bf_data_df = pd.read_csv(csv_file)
bf_data_df.head(1)
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
#
#                     location_details                          county state  \
# 0  East side of Prince William Sound  Valdez-Chitina-Whittier County    ak
#
#   state name State Abr State Name Table State Abr Table season title  \
# 0     Alaska        AK          Alabama              AL   Fall   NaN
#
#    latitude  longitude date  number
# 0       NaN        NaN  NaN  1261.0

# %%
#clean up data to colums needed.
bf_data_df = bf_data_df[['date', 'state', 'title', 'latitude', 'longitude', 'location_details']].copy()
bf_data_df.head(3)
# Out:
#      date state                                              title  latitude  \
# 0     NaN    ak                                                NaN       NaN
# 1     NaN    nj                                                NaN       NaN
# 2  6/7/16    nh  Report 55269: Dawn sighting at Stevens Brook o...  43.41549
#
#    longitude                                   location_details
# 0        NaN                  East side of Prince William Sound
# 1        NaN  the road is off us rt 80, i dont know the exit...
# 2  -72.33093  Close to Claremont down 120 not far from Kings...

# %%
# merge csv files

merge_df = bf_data_df.merge(ufo_data_df, how='left', on='state')
merge_df.head(1)
# Out:
#   date state title  latitude  longitude_x                   location_details  \
# 0  NaN    ak   NaN       NaN          NaN  East side of Prince William Sound
#
#   date posted  longitude_y
# 0  10/30/2006  -149.728889

# %%
merge_df_rename = merge_df.rename(columns={'state': 'State', 'date_x': 'Bigfoot Date', 'latitude_x': 'Bigfoot Latitude', 'longitude_x': 'Bigfoot Longitude',
             'location_details_x': 'Bigfoot Location Details', 'date_y': 'UFO Date', 'latitude_y': 'UFO Latitude',
                               'longitude_y': 'UFO Longitude', 'location_details_y': 'UFO Location Details', 'observed': 'UFO Observed'})
merge_df_rename.head()
# Out:
#   date State title  latitude  Bigfoot Longitude  \
# 0  NaN    ak   NaN       NaN                NaN
# 1  NaN    ak   NaN       NaN                NaN
# 2  NaN    ak   NaN       NaN                NaN
# 3  NaN    ak   NaN       NaN                NaN
# 4  NaN    ak   NaN       NaN                NaN
#
#                     location_details date posted  UFO Longitude
# 0  East side of Prince William Sound  10/30/2006    -149.728889
# 1  East side of Prince William Sound  10/12/2001    -147.716389
# 2  East side of Prince William Sound   12/7/2006    -146.768611
# 3  East side of Prince William Sound   1/28/1999    -161.903334
# 4  East side of Prince William Sound  11/20/2001    -149.567778

# %%
merge_df_rename.count()
# Out:
# Bigfoot Latitude             855921
# Bigfoot Longitude            855921
# State                       1033853
# title                        855921
# date                         855921
# Bigfoot Location Details     881223
# UFO Latitude                 855921
# UFO Longitude                855921
# UFO Location Details         881223
# dtype: int64

# %%
#save csv file
#merge_df_rename.to_csv(r'Resources\bf_ufo.csv')

# %%
#Connect to local database

# <username>:<password>:<pg admin>@local host>:<5432/db_name>""
#rds_connection_string = "<insert user name>:<insert password>@localhost:5432/ufo_bf_db"
#engine = create_engine(f'postgresql://{rds_connection_string}')
